# %% [markdown]
# ## Today's topics
#
# - Angle between two Vector
# - Vector Projection
# - Line vs place vs hyperplane
# - Matrix, Matrix types, Matrix operations

# %% [markdown]
# ---

# %% [markdown]
# # 🔹 Part 1: Angle Between Two Vectors
#
# Formula:
# cos(θ) = (A · B) / (|A| |B|)
#
# Real-World Example:
# Customer feature vectors: [Age, Income]

# %%
import numpy as np
import matplotlib.pyplot as plt

A = np.array([25, 45])
B = np.array([40, 60])

dot_product = np.dot(A, B)
mag_A = np.linalg.norm(A)
mag_B = np.linalg.norm(B)

cos_theta = dot_product / (mag_A * mag_B)
angle = np.degrees(np.arccos(cos_theta))

angle
# Out:
# np.float64(4.635463426902617)

# %%
plt.quiver(0, 0, A[0], A[1], angles="xy", scale_units="xy", scale=1, color="blue")
plt.quiver(0, 0, B[0], B[1], angles="xy", scale_units="xy", scale=1, color="orange")
plt.xlim(0, 50)
plt.ylim(0, 70)
plt.title("Angle Between Two Vectors")
plt.show()

# %% [markdown]
# # 🔹 Part 2: Vector Projection
#
# Vector projection tells us:
#
# How much of one vector lies in the direction of another vector.
#
# It answers:
# 	•	“How much of a is in the direction of b?”
#
# ⸻
#
# 📐 Types of Projection
#
# 1️⃣ Scalar Projection (length only)
#
# 2️⃣ Vector Projection (actual projected vector)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Vector Projection
# Manual + NumPy (Single Block)

import numpy as np

# Define vectors
a = np.array([1, 2])
b = np.array([3, 4])

# -----------------------------
# Step 1: Dot Product
# -----------------------------
dot_product = np.dot(a, b)

# -----------------------------
# Step 2: Magnitude of b
# -----------------------------
magnitude_b = np.linalg.norm(b)

# -----------------------------
# Step 3: Scalar Projection
# -----------------------------
scalar_projection = dot_product / magnitude_b

# -----------------------------
# Step 4: Vector Projection
# -----------------------------
vector_projection = (dot_product / (magnitude_b**2)) * b

# -----------------------------
# Output
# -----------------------------
print("Vector a:", a)
print("Vector b:", b)

print("\nDot Product:", dot_product)
print("Scalar Projection of a onto b:", scalar_projection)
print("Vector Projection of a onto b:", vector_projection)
# Out:
# Vector a: [1 2]
# Vector b: [3 4]
#
# Dot Product: 11
# Scalar Projection of a onto b: 2.2
# Vector Projection of a onto b: [1.32 1.76]

# %%
plt.quiver(0, 0, a[0], a[1], angles="xy", scale_units="xy", scale=1, color="blue")
plt.quiver(0, 0, b[0], b[1], angles="xy", scale_units="xy", scale=1, color="orange")
plt.quiver(0, 0, vector_projection[0], vector_projection[1], angles="xy", scale_units="xy", scale=1)
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.title("Vector Projection")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🔹 Part 3: Line vs Plane vs Hyperplane
#
# Line → 1D object in 2D space
#
# Plane → 2D surface in 3D space
#
# Hyperplane → n-1 dimensional separator in n-dimensional space
#
# Used in Machine Learning as decision boundary.

# %%
x = np.linspace(-5, 5, 100)
y = 2*x + 1

plt.plot(x, y)
plt.title("Line in 2D (y = 2x + 1)")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# # 🔹 Part 4: Matrix
#
# Matrix is a rectangular array of numbers.

# %%
matrix_A = np.array([[1, 2],
                     [3, 4]])

matrix_B = np.array([[5, 6],
                     [7, 8]])

matrix_A, matrix_B
# Out:
# (array([[1, 2],
#         [3, 4]]),
#  array([[5, 6],
#         [7, 8]]))

# %% [markdown]
# # 🔹 Matrix Types
#
# Row Matrix
#
# Column Matrix
#
# Square Matrix
#
# Identity Matrix
#
# Zero Matrix

# %%
row_matrix = np.array([[1, 2, 3]])
column_matrix = np.array([[1], [2], [3]])
identity_matrix = np.eye(3)
zero_matrix = np.zeros((2,2))

row_matrix, column_matrix, identity_matrix, zero_matrix
# Out:
# (array([[1, 2, 3]]),
#  array([[1],
#         [2],
#         [3]]),
#  array([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]]),
#  array([[0., 0.],
#         [0., 0.]]))

# %% [markdown]
# # 🔹 Part 5: Matrix Operations

# %% [markdown]
# ## Matrix Addition

# %%
matrix_A + matrix_B
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %% [markdown]
# ## Matrix Subtraction

# %%
matrix_A - matrix_B
# Out:
# array([[-4, -4],
#        [-4, -4]])

# %% [markdown]
# ## Matrix Multiplication

# %%
np.dot(matrix_A, matrix_B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# ## Transpose

# %%
matrix_A.T
# Out:
# array([[1, 3],
#        [2, 4]])

# %% [markdown]
# ## Determinant

# %%
np.linalg.det(matrix_A)
# Out:
# np.float64(-2.0000000000000004)

# %% [markdown]
# ## Inverse

# %%
np.linalg.inv(matrix_A)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %% [markdown]
# # 📝 Practice Questions
#
# 1. How is angle between vectors calculated?
# 2. What is vector projection?
# 3. Difference between line, plane, hyperplane.
# 4. Define matrix.
# 5. List matrix types.
# 6. Difference between matrix multiplication and element-wise multiplication.

# %% [markdown]
# # 📌 Mini Assignment
#
# Skill vectors:
#
# E1 = [4, 6]
#
# E2 = [5, 8]
#
# Tasks:
# 1. Compute angle between E1 and E2.
# 2. Compute projection of E1 onto E2.
# 3. Visualize vectors and projection.
# 4. Create 2x2 matrix of skills.
# 5. Compute determinant and inverse.
# 6. Explain hyperplane in ML context.
# 7. Provide real-world interpretation.
